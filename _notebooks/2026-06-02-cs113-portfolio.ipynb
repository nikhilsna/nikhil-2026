# %% [markdown]
# ---
# title: "CS 113 — Evidence Summary"
# date: 2026-06-02
# permalink: /notebooks/2026-06-02-cs113-portfolio/
# tags: [cs113, portfolio, evidence]
# categories: [notebook]
# ---
#
# ## Overview
#
# This notebook maps every CS 113 college-credit requirement to a specific file or commit in the codebase. All requirements are met. The backend is a Spring Boot application (port 8585) with JWT auth, Docker deployment, nginx reverse proxy, and a live ML inference endpoint.
#
# **Quick summary by category:**
#
# | Category | # Items | Status |
# |---|:---:|:---:|
# | Data Structures | 7 | All present |
# | Algorithms | 6 | All present |
# | OOP Design | 7 | All present |
# | Software Engineering | 8 | All present |
# | Machine Learning | 2 | All present |
# | Documentation | 3 | All present |
#
# The evidence table below gives the exact file and code for each item.

# %% [markdown]
# <style>
# .p { font-family: 'Segoe UI', sans-serif; font-size: 1.2rem; max-width: 900px; margin: 0 auto; }
# .p table { width:100%; border-collapse:collapse; }
# .p td, .p th { padding: 16px 22px; vertical-align: middle; line-height: 1.6; }
# .p .cat { color:white; font-weight: 700; font-size: 1.05rem; letter-spacing: 1px; text-transform: uppercase; padding: 14px 22px; }
# .p .hdr { background: #f0f2f5; color: #444; font-size: 0.9rem; font-weight: 700; text-transform: uppercase; letter-spacing: 0.5px; }
# .p tr.odd  { background: #fafafa; }
# .p tr.even { background: white; }
# .p .ok { display:inline-block; background:#d4edda; color:#155724; padding: 5px 14px; border-radius: 20px; font-size: 0.9rem; font-weight: 700; white-space: nowrap; }
# .p .src a { font-family: monospace; font-size: 0.95rem; color: #1a56db; text-decoration: underline; word-break: break-all; }
# .p .how { font-family: monospace; font-size: 1rem; color: #1a1a2e; background: #f4f4f8; padding: 5px 12px; border-radius: 4px; display: inline-block; line-height: 1.7; }
# </style>
#
# <div class='p'><table>
#
# <tr><td colspan='4' class='cat' style='background:#283593;'>&#9632;&nbsp; Data Structures</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>HashSet</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/mortevision/nativesocket/WebSocketHandler.java#L15' target='_blank'>WebSocketHandler.java:15</a></td> <td><code class='how'>Set&lt;WebSocketSession&gt; sessions = new HashSet&lt;&gt;()</code></td></tr>
# <tr class='even'><td>HashMap</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/Person.java#L153' target='_blank'>Person.java:153</a></td> <td><code class='how'>Map&lt;String, Map&lt;String,Object&gt;&gt; stats = new HashMap&lt;&gt;()</code></td></tr>
# <tr class='odd'> <td>Stack</td>      <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/blob/main/_notebooks/2026-03-23-calc.ipynb' target='_blank'>calc.ipynb</a></td> <td><code class='how'>Stack&lt;Double&gt; operandStack &rarr; push / pop (RPN)</code></td></tr>
# <tr class='even'><td>Queue</td>      <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/blob/main/_notebooks/2026-03-23-calc.ipynb' target='_blank'>calc.ipynb</a></td> <td><code class='how'>Queue&lt;String&gt; tokenQueue = new LinkedList&lt;&gt;() (FIFO)</code></td></tr>
# <tr class='odd'> <td>Graph + BFS</td><td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/assignments/AssignmentGraphService.java' target='_blank'>AssignmentGraphService.java</a></td> <td><code class='how'>Assignment &harr; Person &harr; Submission via ArrayDeque, O(V+E)</code></td></tr>
# <tr class='even'><td>List</td>       <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/assignments/Assignment.java' target='_blank'>Assignment.java</a></td> <td><code class='how'>@OneToMany List&lt;AssignmentSubmission&gt; submissions</code></td></tr>
# <tr class='odd'> <td>Set (roles)</td><td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/Person.java#L185' target='_blank'>Person.java:185</a></td> <td><code class='how'>Set&lt;PersonRole&gt; roles @ManyToMany (unique per person)</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#2e7d32;'>&#9632;&nbsp; Algorithms</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>Sorting &mdash; Comparator</td>  <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/crypto/RankingsController.java' target='_blank'>RankingsController.java</a></td> <td><code class='how'>.sorted(Comparator.comparingDouble(Bank::getBalance).reversed())</code></td></tr>
# <tr class='even'><td>Sorting &mdash; Merge/Bubble</td> <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/blob/main/_notebooks/2025-04-21-bigO.ipynb' target='_blank'>bigO.ipynb</a></td> <td><code class='how'>mergeSort O(n log n) vs bubbleSort O(n&sup2;) &mdash; empirical timing</code></td></tr>
# <tr class='odd'> <td>Searching</td>                   <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/blob/main/_notebooks/2025-04-07-lstfltng.ipynb' target='_blank'>lstfltng.ipynb</a></td> <td><code class='how'>binarySearch O(log n) &bull; linear filter O(n)</code></td></tr>
# <tr class='even'><td>Hashing</td>                     <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/system/MvcConfig.java#L23' target='_blank'>MvcConfig.java:23</a></td> <td><code class='how'>new BCryptPasswordEncoder() &mdash; salted, adaptive cost 2^10</code></td></tr>
# <tr class='odd'> <td>Big-O Analysis</td>              <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/blob/main/_notebooks/2025-04-21-bigO.ipynb' target='_blank'>bigO.ipynb</a> + <a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/assignments/AssignmentGraphService.java' target='_blank'>AssignmentGraphService</a></td> <td><code class='how'>O(1) &bull; O(log n) &bull; O(n log n) &bull; O(n&sup2;) &bull; O(V+E)</code></td></tr>
# <tr class='even'><td>Comparator &mdash; date sort</td> <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/slack/CalendarIssueService.java#L56' target='_blank'>CalendarIssueService.java:56</a></td> <td><code class='how'>issues.sort(Comparator.comparing(CalendarIssue::getDueDate))</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#6a1b9a;'>&#9632;&nbsp; OOP Design</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>Abstract Class</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/groups/Submitter.java' target='_blank'>Submitter.java</a> / <a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/identity/User.java' target='_blank'>User.java</a></td> <td><code class='how'>abstract class Submitter &nbsp;/&nbsp; abstract class User</code></td></tr>
# <tr class='even'><td>Inheritance</td>       <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/Person.java' target='_blank'>Person.java</a></td> <td><code class='how'>Person extends Submitter &nbsp;&bull;&nbsp; Student extends User</code></td></tr>
# <tr class='odd'> <td>Polymorphism</td>      <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/mortevision/nativesocket/WebSocketHandler.java' target='_blank'>WebSocketHandler.java</a></td> <td><code class='how'>@Override &times;3 &rarr; afterConnectionEstablished / Closed / handleTextMessage</code></td></tr>
# <tr class='even'><td>Interface</td>         <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/assignments/AssignmentJpaRepository.java' target='_blank'>AssignmentJpaRepository.java</a></td> <td><code class='how'>interface extends JpaRepository&lt;Assignment, Long&gt;</code></td></tr>
# <tr class='odd'> <td>Encapsulation</td>     <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/Person.java' target='_blank'>Person.java</a></td> <td><code class='how'>private final &bull; @JsonIgnore &bull; getters/setters</code></td></tr>
# <tr class='even'><td>Comparable</td>        <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/Person.java#L313' target='_blank'>Person.java:313</a></td> <td><code class='how'>implements Comparable&lt;Person&gt; &rarr; compareTo(name)</code></td></tr>
# <tr class='odd'> <td>Design Pattern (MVC)</td><td><span class='ok'>&#10003; PRESENT</span></td><td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/blob/main/_notebooks/2026-03-19-SRP.ipynb' target='_blank'>SRP.ipynb</a></td> <td><code class='how'>Controller &rarr; Service &rarr; Repository &rarr; Entity</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#e65100;'>&#9632;&nbsp; Software Engineering</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>REST API</td>           <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/PersonApiController.java' target='_blank'>PersonApiController.java</a></td> <td><code class='how'>GET / POST / PUT / DELETE + ResponseEntity&lt;&gt; &mdash; 100+ endpoints</code></td></tr>
# <tr class='even'><td>JPA / Hibernate</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/Person.java' target='_blank'>Person.java</a> / <a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/assignments/Assignment.java' target='_blank'>Assignment.java</a></td> <td><code class='how'>@Entity @OneToMany @ManyToMany @JoinTable</code></td></tr>
# <tr class='odd'> <td>JUnit Tests</td>        <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/tree/master/src/test' target='_blank'>src/test (9 files)</a></td> <td><code class='how'>@SpringBootTest + @MockBean &mdash; 18 @Test methods</code></td></tr>
# <tr class='even'><td>Maven Build</td>        <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/pom.xml' target='_blank'>pom.xml</a></td> <td><code class='how'>Spring Boot &bull; Smile 3.0.1 &bull; Weka 3.8.6 &bull; BCrypt</code></td></tr>
# <tr class='odd'> <td>Docker</td>             <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/Dockerfile' target='_blank'>Dockerfile</a> / <a href='https://github.com/nikhilsna/spring/blob/master/docker-compose.yml' target='_blank'>docker-compose.yml</a></td> <td><code class='how'>eclipse-temurin:21 multi-stage &rarr; EXPOSE 8585 8589</code></td></tr>
# <tr class='even'><td>nginx</td>              <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/nginx_spring_8585_8589.conf' target='_blank'>nginx_spring_8585_8589.conf</a></td> <td><code class='how'>proxy_pass :8585 &bull; WSS upgrade &bull; Let&apos;s Encrypt TLS</code></td></tr>
# <tr class='odd'> <td>CI / CD</td>            <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/.github/workflows/build.yml' target='_blank'>.github/workflows/build.yml</a></td> <td><code class='how'>push &rarr; setup-java@v4 (JDK 21) &rarr; ./mvnw -B test &rarr; deploy</code></td></tr>
# <tr class='even'><td>Authenticated CRUD</td> <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/person/PersonApiController.java' target='_blank'>PersonApiController.java</a></td> <td><code class='how'>BCrypt auth &bull; GET/POST/PUT/DELETE &bull; role-based access</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#00695c;'>&#9632;&nbsp; Machine Learning</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>Random Forest / Tree</td><td><span class='ok'>&#10003; PRESENT</span></td><td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/gradePrediction/GradeTrainingController.java#L146' target='_blank'>GradeTrainingController.java:146</a></td> <td><code class='how'>RandomForest.fit(formula, dataFrame) &rarr; /train endpoint (Smile)</code></td></tr>
# <tr class='even'><td>ML Pipeline</td>         <td><span class='ok'>&#10003; PRESENT</span></td><td class='src'><a href='https://github.com/nikhilsna/spring/blob/master/src/main/java/com/open/spring/mvc/gradePrediction/GradeTrainingController.java#L43' target='_blank'>GradeTrainingController.java:43</a></td> <td><code class='how'>HashMap encoders &rarr; DataFrame &rarr; fit &rarr; /predict inference</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#b71c1c;'>&#9632;&nbsp; Documentation</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>API Docs (Postman)</td><td><span class='ok'>&#10003; PRESENT</span></td><td class='src'><a href='https://github.com/nikhilsna/spring' target='_blank'>nikhilsna/spring</a></td> <td><code class='how'>14 folders &bull; 80+ endpoints &bull; {{base_url}} variable</code></td></tr>
# <tr class='even'><td>Blog Portfolio</td>    <td><span class='ok'>&#10003; PRESENT</span></td><td class='src'><a href='https://github.com/nikhilsna/nikhil-2026/tree/main/_notebooks' target='_blank'>nikhil-2026/_notebooks</a></td> <td><code class='how'>FRQ&times;4 &bull; bigO &bull; SRP &bull; calc &bull; year-reflection</code></td></tr>
# <tr class='odd'> <td>Project Impact</td>   <td><span class='ok'>&#10003; PRESENT</span></td><td class='src'><a href='https://opencodingsociety.com' target='_blank'>opencodingsociety.com</a></td> <td><code class='how'>Queue &bull; Grade Requests &bull; Capstone &bull; Calendar &bull; WS &bull; Bank &bull; ML &bull; BFS</code></td></tr>
#
# </table></div>

# %% [markdown]
# ## Requirements Met — Summary
#
# All 12 CS 113 college-credit requirements are satisfied.
#
# <table style="color:white; border-collapse:collapse; width:100%; max-width:900px;">
#   <thead>
#     <tr style="background:#1e293b;">
#       <th style="padding:12px 16px; text-align:left; border-bottom:1px solid #334155;">Requirement</th>
#       <th style="padding:12px 16px; text-align:left; border-bottom:1px solid #334155;">Met via</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#0f172a;"><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">Backend Java Spring Boot + JPA/Hibernate</td><td style="padding:12px 16px; border-bottom:1px solid #1e293b;"><code style="color:#93c5fd;">nikhilsna/spring</code> — <code style="color:#93c5fd;">@Entity</code>, <code style="color:#93c5fd;">@OneToMany</code>, <code style="color:#93c5fd;">@ManyToMany</code> throughout</td></tr>
#     <tr style="background:#1e293b;"><td style="padding:12px 16px; border-bottom:1px solid #334155;">3+ data structures</td><td style="padding:12px 16px; border-bottom:1px solid #334155;">HashSet, HashMap, Stack, Queue, Graph, List, Set — all in production code</td></tr>
#     <tr style="background:#0f172a;"><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">2+ algorithms with Big-O</td><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">Merge/bubble sort, binary search, BCrypt hashing, BFS — complexity documented</td></tr>
#     <tr style="background:#1e293b;"><td style="padding:12px 16px; border-bottom:1px solid #334155;">Complete OOP (all 4 pillars)</td><td style="padding:12px 16px; border-bottom:1px solid #334155;">Encapsulation, Inheritance, Polymorphism, Abstraction — see table above</td></tr>
#     <tr style="background:#0f172a;"><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">RESTful API + error handling</td><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">100+ endpoints, <code style="color:#93c5fd;">ResponseEntity&lt;?&gt;</code> with correct HTTP status codes</td></tr>
#     <tr style="background:#1e293b;"><td style="padding:12px 16px; border-bottom:1px solid #334155;">Database + entity relationships</td><td style="padding:12px 16px; border-bottom:1px solid #334155;"><code style="color:#93c5fd;">@JoinTable</code>, <code style="color:#93c5fd;">@OneToMany</code>, <code style="color:#93c5fd;">@ManyToMany</code> — normalized MySQL schema</td></tr>
#     <tr style="background:#0f172a;"><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">JUnit tests</td><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">9 test files, 18 <code style="color:#93c5fd;">@Test</code> methods, <code style="color:#93c5fd;">@SpringBootTest</code> + <code style="color:#93c5fd;">@MockBean</code></td></tr>
#     <tr style="background:#1e293b;"><td style="padding:12px 16px; border-bottom:1px solid #334155;">Docker + docker-compose</td><td style="padding:12px 16px; border-bottom:1px solid #334155;"><code style="color:#93c5fd;">eclipse-temurin:21</code> multi-stage build, ports 8585 and 8589</td></tr>
#     <tr style="background:#0f172a;"><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">Custom domain + nginx</td><td style="padding:12px 16px; border-bottom:1px solid #1e293b;"><code style="color:#93c5fd;">nginx_spring_8585_8589.conf</code> — HTTPS proxy, WSS upgrade, Let's Encrypt TLS</td></tr>
#     <tr style="background:#1e293b;"><td style="padding:12px 16px; border-bottom:1px solid #334155;">CI/CD pipeline</td><td style="padding:12px 16px; border-bottom:1px solid #334155;"><code style="color:#93c5fd;">build.yml</code> — Maven build + JUnit on every push via GitHub Actions</td></tr>
#     <tr style="background:#0f172a;"><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">Blog portfolio</td><td style="padding:12px 16px; border-bottom:1px solid #1e293b;">This site — FRQ×4, bigO, SRP, calc, year-reflection, capstone notebooks</td></tr>
#     <tr style="background:#1e293b;"><td style="padding:12px 16px;">Project impact in production</td><td style="padding:12px 16px;">Live on <code style="color:#93c5fd;">opencodingsociety.com</code> — used by the class</td></tr>
#   </tbody>
# </table>
