# %% [markdown]
# ---
# layout: post
# title: "AP CSA Exam Reflection"
# description: "AP Computer Science A 2026 — study data and exam reflection"
# type: tangibles
# comments: true
# ---

# %% [markdown]
# <div style="font-family: sans-serif; max-width: 720px; margin: auto;">
#
#   <!-- Header -->
#   <div style="background: linear-gradient(135deg, #1a1a2e, #16213e); color: white; border-radius: 12px; padding: 24px 28px; margin-bottom: 20px;">
#     <h2 style="margin: 0 0 4px 0; font-size: 1.6em; letter-spacing: 0.5px;">AP CSA Exam — 2026</h2>
#     <p style="margin: 0; opacity: 0.6; font-size: 0.9em;">AP Computer Science A · Del Norte High School</p>
#   </div>
#
#   <!-- Practice Exam Cards -->
#   <div style="display: flex; gap: 16px; margin-bottom: 20px;">
#     <div style="flex: 1; background: #e8f5e9; border-left: 5px solid #43a047; border-radius: 10px; padding: 18px 20px;">
#       <div style="font-size: 0.75em; color: #555; text-transform: uppercase; letter-spacing: 1px; margin-bottom: 4px;">Practice Exam 1</div>
#       <div style="font-size: 2.2em; font-weight: bold; color: #2e7d32;">81%</div>
#       <div style="color: #777; font-size: 0.85em;">34 / 42</div>
#     </div>
#     <div style="flex: 1; background: #e8f5e9; border-left: 5px solid #66bb6a; border-radius: 10px; padding: 18px 20px;">
#       <div style="font-size: 0.75em; color: #555; text-transform: uppercase; letter-spacing: 1px; margin-bottom: 4px;">Practice Exam 2</div>
#       <div style="font-size: 2.2em; font-weight: bold; color: #2e7d32;">76%</div>
#       <div style="color: #777; font-size: 0.85em;">32 / 42</div>
#     </div>
#   </div>
#
#   <!-- Unit Performance -->
#   <div style="border-radius: 10px; overflow: hidden; margin-bottom: 20px; border: 1px solid #e0e0e0;">
#     <div style="background: #3949ab; color: white; padding: 12px 18px; font-weight: bold; font-size: 0.85em; letter-spacing: 1px; text-transform: uppercase;">Unit Performance</div>
#     <table style="width: 100%; border-collapse: collapse; font-size: 0.9em;">
#       <tr style="background: #f5f5f5; color: #888; font-size: 0.8em; text-transform: uppercase; letter-spacing: 0.5px;">
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">Unit</th>
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">Topic</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Score</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Verdict</th>
#       </tr>
#       <tr>
#         <td style="padding: 11px 18px; color: #888;">U1</td>
#         <td style="padding: 11px 18px;">Objects &amp; Methods</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold;">75%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #e3f2fd; color: #1565c0; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Solid</span></td>
#       </tr>
#       <tr style="background: #fafafa;">
#         <td style="padding: 11px 18px; color: #888;">U2</td>
#         <td style="padding: 11px 18px;">Selection &amp; Iteration</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold;">85%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #e8f5e9; color: #2e7d32; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Strong</span></td>
#       </tr>
#       <tr>
#         <td style="padding: 11px 18px; color: #888;">U3</td>
#         <td style="padding: 11px 18px;">Class Creation</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold;">71%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #ffebee; color: #c62828; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Weak</span></td>
#       </tr>
#       <tr style="background: #fafafa;">
#         <td style="padding: 11px 18px; color: #888;">U4</td>
#         <td style="padding: 11px 18px;">Data Collections</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold;">81%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #e3f2fd; color: #1565c0; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Solid</span></td>
#       </tr>
#     </table>
#   </div>
#
#   <!-- FRQ Breakdown -->
#   <div style="border-radius: 10px; overflow: hidden; margin-bottom: 20px; border: 1px solid #e0e0e0;">
#     <div style="background: #6a1b9a; color: white; padding: 12px 18px; font-weight: bold; font-size: 0.85em; letter-spacing: 1px; text-transform: uppercase;">FRQ Breakdown</div>
#     <table style="width: 100%; border-collapse: collapse; font-size: 0.9em;">
#       <tr style="background: #f5f5f5; color: #888; font-size: 0.8em; text-transform: uppercase; letter-spacing: 0.5px;">
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">FRQ</th>
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">Topic</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Difficulty</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Confidence</th>
#       </tr>
#       <tr>
#         <td style="padding: 11px 18px; font-weight: bold; color: #555;">1</td>
#         <td style="padding: 11px 18px;">Methods &amp; Control Flow</td>
#         <td style="padding: 11px 18px; text-align: center; color: #43a047; font-weight: bold;">2 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #43a047; font-weight: bold;">5 / 5</td>
#       </tr>
#       <tr style="background: #fafafa;">
#         <td style="padding: 11px 18px; font-weight: bold; color: #555;">2</td>
#         <td style="padding: 11px 18px;">Classes</td>
#         <td style="padding: 11px 18px; text-align: center; color: #f9a825; font-weight: bold;">3 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #43a047; font-weight: bold;">4 / 5</td>
#       </tr>
#       <tr>
#         <td style="padding: 11px 18px; font-weight: bold; color: #555;">3</td>
#         <td style="padding: 11px 18px;">Array / ArrayList</td>
#         <td style="padding: 11px 18px; text-align: center; color: #f9a825; font-weight: bold;">3 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #43a047; font-weight: bold;">4 / 5</td>
#       </tr>
#       <tr style="background: #fff3e0;">
#         <td style="padding: 11px 18px; font-weight: bold; color: #e65100;">4 ⚠</td>
#         <td style="padding: 11px 18px; font-weight: bold; color: #e65100;">2D Arrays</td>
#         <td style="padding: 11px 18px; text-align: center; color: #c62828; font-weight: bold;">5 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #c62828; font-weight: bold;">2 / 5</td>
#       </tr>
#     </table>
#   </div>
#
#   <!-- Takeaway -->
#   <div style="background: linear-gradient(135deg, #1b5e20, #2e7d32); color: white; border-radius: 10px; padding: 16px 22px; font-size: 0.95em; line-height: 1.7;">
#     <strong>Takeaway —</strong> Consistent practice paid off. Both exams cleared 75%. U3 (Class Creation) and FRQ 4 (2D Arrays) were the clear weak spots — nested loop logic under time pressure is where points were left on the table.
#   </div>
#
# </div>
