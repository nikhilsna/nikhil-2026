# %% [markdown]
# ---
# layout: post
# title: "AP CSA Exam Reflection"
# description: "AP Computer Science A 2026 — study data and exam reflection"
# type: tangibles
# comments: true
# ---

# %% [markdown]
# <img src="{{site.baseurl}}/images/ap_csa_practice1_mcq.png" alt="Practice Exam 1 MCQ Results" style="width:100%;border-radius:8px;margin-bottom:24px;">

# %% [markdown]
# <div style="font-family: sans-serif; max-width: 720px; margin: auto; color: white;">
#
#   <div style="background: linear-gradient(135deg, #1a1a2e, #16213e); color: white; border-radius: 12px; padding: 24px 28px; margin-bottom: 20px;">
#     <h2 style="margin: 0 0 4px 0; font-size: 1.6em; letter-spacing: 0.5px; color: white;">AP CSA Exam — 2026</h2>
#     <p style="margin: 0; opacity: 0.6; font-size: 0.9em; color: white;">AP Computer Science A · Del Norte High School</p>
#   </div>
#
#   <div style="background: #1e293b; border-radius: 10px; padding: 22px 26px; margin-bottom: 20px;">
#     <p style="font-size: 1.3em; font-weight: bold; line-height: 1.8; margin: 0; color: white;">This past year in AP CSA was a real grind — but the kind that actually pays off. I put in consistent work across all four units throughout the year, and both of my practice exams came in above 75%. Selection and Iteration was my strongest area, while Class Creation consistently gave me trouble. On the free response section, FRQs 1 through 3 were manageable — I went in with strong confidence and the difficulty reflected that. FRQ 4 on 2D Arrays was a completely different story. Nested loop logic under timed exam conditions exposed a gap I knew existed but hadn't fully closed. Overall the exam went well, and the year of prep made a real difference when it counted.</p>
#   </div>
#
#   <div style="display: flex; gap: 16px; margin-bottom: 20px;">
#     <div style="flex: 1; background: #0f2d1a; border-left: 5px solid #43a047; border-radius: 10px; padding: 18px 20px;">
#       <div style="font-size: 0.75em; color: #94a3b8; text-transform: uppercase; letter-spacing: 1px; margin-bottom: 4px;">Practice Exam 1</div>
#       <div style="font-size: 2.2em; font-weight: bold; color: #4ade80;">81%</div>
#       <div style="color: #94a3b8; font-size: 0.85em;">34 / 42</div>
#     </div>
#     <div style="flex: 1; background: #0f2d1a; border-left: 5px solid #66bb6a; border-radius: 10px; padding: 18px 20px;">
#       <div style="font-size: 0.75em; color: #94a3b8; text-transform: uppercase; letter-spacing: 1px; margin-bottom: 4px;">Practice Exam 2</div>
#       <div style="font-size: 2.2em; font-weight: bold; color: #4ade80;">76%</div>
#       <div style="color: #94a3b8; font-size: 0.85em;">32 / 42</div>
#     </div>
#   </div>
#
#   <div style="border-radius: 10px; overflow: hidden; margin-bottom: 20px;">
#     <div style="background: #3949ab; color: white; padding: 12px 18px; font-weight: bold; font-size: 0.85em; letter-spacing: 1px; text-transform: uppercase;">Unit Performance</div>
#     <table style="width: 100%; border-collapse: collapse; font-size: 0.9em;">
#       <tr style="background: #1e293b; color: #94a3b8; font-size: 0.8em; text-transform: uppercase; letter-spacing: 0.5px;">
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">Unit</th>
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">Topic</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Score</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Verdict</th>
#       </tr>
#       <tr style="background: #0f172a;">
#         <td style="padding: 11px 18px; color: #94a3b8;">U1</td>
#         <td style="padding: 11px 18px; color: white;">Objects &amp; Methods</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold; color: white;">75%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #1e3a5f; color: #93c5fd; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Solid</span></td>
#       </tr>
#       <tr style="background: #1e293b;">
#         <td style="padding: 11px 18px; color: #94a3b8;">U2</td>
#         <td style="padding: 11px 18px; color: white;">Selection &amp; Iteration</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold; color: white;">85%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #0f2d1a; color: #4ade80; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Strong</span></td>
#       </tr>
#       <tr style="background: #0f172a;">
#         <td style="padding: 11px 18px; color: #94a3b8;">U3</td>
#         <td style="padding: 11px 18px; color: white;">Class Creation</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold; color: white;">71%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #3b0a0a; color: #fca5a5; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Weak</span></td>
#       </tr>
#       <tr style="background: #1e293b;">
#         <td style="padding: 11px 18px; color: #94a3b8;">U4</td>
#         <td style="padding: 11px 18px; color: white;">Data Collections</td>
#         <td style="padding: 11px 18px; text-align: center; font-weight: bold; color: white;">81%</td>
#         <td style="padding: 11px 18px; text-align: center;"><span style="background: #1e3a5f; color: #93c5fd; border-radius: 20px; padding: 3px 14px; font-size: 0.8em; font-weight: bold;">Solid</span></td>
#       </tr>
#     </table>
#   </div>
#
#   <div style="border-radius: 10px; overflow: hidden; margin-bottom: 20px;">
#     <div style="background: #6a1b9a; color: white; padding: 12px 18px; font-weight: bold; font-size: 0.85em; letter-spacing: 1px; text-transform: uppercase;">FRQ Breakdown</div>
#     <table style="width: 100%; border-collapse: collapse; font-size: 0.9em;">
#       <tr style="background: #1e293b; color: #94a3b8; font-size: 0.8em; text-transform: uppercase; letter-spacing: 0.5px;">
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">FRQ</th>
#         <th style="padding: 10px 18px; text-align: left; font-weight: 600;">Topic</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Difficulty</th>
#         <th style="padding: 10px 18px; text-align: center; font-weight: 600;">Confidence</th>
#       </tr>
#       <tr style="background: #0f172a;">
#         <td style="padding: 11px 18px; font-weight: bold; color: #94a3b8;">1</td>
#         <td style="padding: 11px 18px; color: white;">Methods &amp; Control Flow</td>
#         <td style="padding: 11px 18px; text-align: center; color: #4ade80; font-weight: bold;">2 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #4ade80; font-weight: bold;">5 / 5</td>
#       </tr>
#       <tr style="background: #1e293b;">
#         <td style="padding: 11px 18px; font-weight: bold; color: #94a3b8;">2</td>
#         <td style="padding: 11px 18px; color: white;">Classes</td>
#         <td style="padding: 11px 18px; text-align: center; color: #fbbf24; font-weight: bold;">3 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #4ade80; font-weight: bold;">4 / 5</td>
#       </tr>
#       <tr style="background: #0f172a;">
#         <td style="padding: 11px 18px; font-weight: bold; color: #94a3b8;">3</td>
#         <td style="padding: 11px 18px; color: white;">Array / ArrayList</td>
#         <td style="padding: 11px 18px; text-align: center; color: #fbbf24; font-weight: bold;">3 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #4ade80; font-weight: bold;">4 / 5</td>
#       </tr>
#       <tr style="background: #3b0a0a;">
#         <td style="padding: 11px 18px; font-weight: bold; color: #fca5a5;">4 ⚠</td>
#         <td style="padding: 11px 18px; font-weight: bold; color: #fca5a5;">2D Arrays</td>
#         <td style="padding: 11px 18px; text-align: center; color: #f87171; font-weight: bold;">5 / 5</td>
#         <td style="padding: 11px 18px; text-align: center; color: #f87171; font-weight: bold;">2 / 5</td>
#       </tr>
#     </table>
#   </div>
#
#   <div style="background: linear-gradient(135deg, #1b5e20, #2e7d32); color: white; border-radius: 10px; padding: 16px 22px; font-size: 0.95em; line-height: 1.7;">
#     <strong>Takeaway —</strong> Consistent practice paid off. Both exams cleared 75%. U3 (Class Creation) and FRQ 4 (2D Arrays) were the clear weak spots — nested loop logic under time pressure is where points were left on the table.
#   </div>
#
# </div>

# %% [markdown]
# <div style="max-width:720px; margin: 24px auto 0;">
#   <div style="background:#1e293b; border-radius:10px; overflow:hidden;">
#     <div style="background:#0f3460; color:white; padding:12px 18px; font-weight:bold; font-size:0.85em; letter-spacing:1px; text-transform:uppercase;">College Board — Progress Check Scores</div>
#     <div style="padding:16px;">
#       <img src="{{site.baseurl}}/images/ap_csa_progress_checks.png" alt="AP CSA Progress Check Scores" style="width:100%; border-radius:6px;">
#     </div>
#   </div>
# </div>
