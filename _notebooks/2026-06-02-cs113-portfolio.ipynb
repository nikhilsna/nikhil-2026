# %% [markdown]
# ---
# title: "CS 113 — Evidence Summary"
# date: 2026-06-02
# permalink: /notebooks/2026-06-02-cs113-portfolio/
# tags: [cs113, portfolio, evidence]
# categories: [notebook]
# ---
#
# ## Overview
#
# This notebook maps every CS 113 college-credit requirement to a specific file or commit in the codebase. All requirements are met. The backend is a Spring Boot application (port 8585) with JWT auth, Docker deployment, nginx reverse proxy, and a live ML inference endpoint.
#
# **Quick summary by category:**
#
# | Category | # Items | Status |
# |---|:---:|:---:|
# | Data Structures | 7 | All present |
# | Algorithms | 6 | All present |
# | OOP Design | 7 | All present |
# | Software Engineering | 8 | All present |
# | Machine Learning | 2 | All present |
# | Documentation | 3 | All present |
#
# The evidence table below gives the exact file and code for each item.

# %% [markdown]
# <style>
# .p { font-family: 'Segoe UI', sans-serif; font-size: 1rem; }
# .p table { width:100%; border-collapse:collapse; }
# .p td, .p th { padding: 12px 18px; vertical-align: middle; line-height: 1.5; }
# .p .cat { color:white; font-weight: 700; font-size: 0.95rem; letter-spacing: 1px; text-transform: uppercase; padding: 12px 18px; }
# .p .hdr { background: #f0f2f5; color: #555; font-size: 0.85rem; font-weight: 700; text-transform: uppercase; letter-spacing: 0.5px; }
# .p tr.odd  { background: #fafafa; }
# .p tr.even { background: white; }
# .p .ok { display:inline-block; background:#d4edda; color:#155724; padding: 4px 12px; border-radius: 20px; font-size: 0.85rem; font-weight: 700; white-space: nowrap; }
# .p .src { font-family: monospace; font-size: 0.9rem; color: #555; }
# .p .how { font-family: monospace; font-size: 0.88rem; color: #1a1a2e; background: #f4f4f8; padding: 4px 10px; border-radius: 4px; display: inline-block; line-height: 1.6; }
# </style>
#
# <div class='p'><table>
#
# <tr><td colspan='4' class='cat' style='background:#283593;'>&#9632;&nbsp; Data Structures</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>HashSet</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>WebSocketHandler.java:11</td>         <td><code class='how'>Set&lt;WebSocketSession&gt; sessions = new HashSet&lt;&gt;()</code></td></tr>
# <tr class='even'><td>HashMap</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Person.java:153</td>                  <td><code class='how'>Map&lt;String, Map&lt;String,Object&gt;&gt; stats = new HashMap&lt;&gt;()</code></td></tr>
# <tr class='odd'> <td>Stack</td>      <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>calc.ipynb</td>                       <td><code class='how'>Stack&lt;Double&gt; operandStack &rarr; push / pop (RPN)</code></td></tr>
# <tr class='even'><td>Queue</td>      <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>calc.ipynb</td>                       <td><code class='how'>Queue&lt;String&gt; tokenQueue = new LinkedList&lt;&gt;() (FIFO)</code></td></tr>
# <tr class='odd'> <td>Graph + BFS</td><td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>AssignmentGraphService.java</td>       <td><code class='how'>Assignment &harr; Person &harr; Submission via ArrayDeque, O(V+E)</code></td></tr>
# <tr class='even'><td>List</td>       <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Assignment.java:58</td>               <td><code class='how'>@OneToMany List&lt;AssignmentSubmission&gt; submissions</code></td></tr>
# <tr class='odd'> <td>Set (roles)</td><td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Person.java:185</td>                  <td><code class='how'>Set&lt;PersonRole&gt; roles @ManyToMany (unique per person)</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#2e7d32;'>&#9632;&nbsp; Algorithms</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>Sorting &mdash; Comparator</td>  <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>RankingsController.java</td>          <td><code class='how'>.sorted(Comparator.comparingDouble(Bank::getBalance).reversed())</code></td></tr>
# <tr class='even'><td>Sorting &mdash; Merge/Bubble</td> <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>bigO.ipynb</td>                       <td><code class='how'>mergeSort O(n log n) vs bubbleSort O(n&sup2;) &mdash; empirical timing</code></td></tr>
# <tr class='odd'> <td>Searching</td>                   <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>lstfltng.ipynb</td>                   <td><code class='how'>binarySearch O(log n) &bull; linear filter O(n)</code></td></tr>
# <tr class='even'><td>Hashing</td>                     <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>MvcConfig.java:23</td>                <td><code class='how'>new BCryptPasswordEncoder() &mdash; salted, adaptive cost 2^10</code></td></tr>
# <tr class='odd'> <td>Big-O Analysis</td>              <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>bigO.ipynb + AssignmentGraphService</td><td><code class='how'>O(1) &bull; O(log n) &bull; O(n log n) &bull; O(n&sup2;) &bull; O(V+E)</code></td></tr>
# <tr class='even'><td>Comparator &mdash; date sort</td> <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>CalendarIssueService.java:56</td>     <td><code class='how'>issues.sort(Comparator.comparing(CalendarIssue::getDueDate))</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#6a1b9a;'>&#9632;&nbsp; OOP Design</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>Abstract Class</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Submitter.java:26, User.java:24</td>  <td><code class='how'>abstract class Submitter &nbsp;/&nbsp; abstract class User</code></td></tr>
# <tr class='even'><td>Inheritance</td>       <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Person.java:66</td>                <td><code class='how'>Person extends Submitter &nbsp;&bull;&nbsp; Student extends User</code></td></tr>
# <tr class='odd'> <td>Polymorphism</td>      <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>WebSocketHandler.java</td>          <td><code class='how'>@Override &times;3 &rarr; afterConnectionEstablished / Closed / handleTextMessage</code></td></tr>
# <tr class='even'><td>Interface</td>         <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>AssignmentJpaRepository.java</td>   <td><code class='how'>interface extends JpaRepository&lt;Assignment, Long&gt;</code></td></tr>
# <tr class='odd'> <td>Encapsulation</td>     <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Person.java</td>                   <td><code class='how'>private final &bull; @JsonIgnore &bull; getters/setters</code></td></tr>
# <tr class='even'><td>Comparable</td>        <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Person.java:313</td>               <td><code class='how'>implements Comparable&lt;Person&gt; &rarr; compareTo(name)</code></td></tr>
# <tr class='odd'> <td>Design Pattern (MVC)</td><td><span class='ok'>&#10003; PRESENT</span></td><td class='src'>SRP.ipynb / AutoTriage</td>         <td><code class='how'>Controller &rarr; Service &rarr; Repository &rarr; Entity</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#e65100;'>&#9632;&nbsp; Software Engineering</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>REST API</td>           <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>15+ @RestController files</td>      <td><code class='how'>GET / POST / PUT / DELETE + ResponseEntity&lt;&gt; &mdash; 100+ endpoints</code></td></tr>
# <tr class='even'><td>JPA / Hibernate</td>    <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Person.java, Assignment.java</td>  <td><code class='how'>@Entity @OneToMany @ManyToMany @JoinTable</code></td></tr>
# <tr class='odd'> <td>JUnit Tests</td>        <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>9 test files</td>                  <td><code class='how'>@SpringBootTest + @MockBean &mdash; 18 @Test methods</code></td></tr>
# <tr class='even'><td>Maven Build</td>        <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>pom.xml</td>                       <td><code class='how'>Spring Boot &bull; Smile 3.0.1 &bull; Weka 3.8.6 &bull; BCrypt</code></td></tr>
# <tr class='odd'> <td>Docker</td>             <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>Dockerfile + docker-compose.yml</td><td><code class='how'>eclipse-temurin:21 multi-stage &rarr; EXPOSE 8585 8589</code></td></tr>
# <tr class='even'><td>nginx</td>              <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>nginx_spring_8585_8589.conf</td>   <td><code class='how'>proxy_pass :8585 &bull; WSS upgrade &bull; Let&apos;s Encrypt TLS</code></td></tr>
# <tr class='odd'> <td>CI / CD</td>            <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>.github/workflows/build.yml</td>   <td><code class='how'>push &rarr; setup-java@v4 (JDK 21) &rarr; ./mvnw -B test &rarr; deploy</code></td></tr>
# <tr class='even'><td>Authenticated CRUD</td> <td><span class='ok'>&#10003; PRESENT</span></td> <td class='src'>PersonApiController.java</td>      <td><code class='how'>BCrypt auth &bull; GET/POST/PUT/DELETE &bull; role-based access</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#00695c;'>&#9632;&nbsp; Machine Learning</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>Random Forest / Tree</td><td><span class='ok'>&#10003; PRESENT</span></td><td class='src'>GradeTrainingController.java:146</td><td><code class='how'>RandomForest.fit(formula, dataFrame) &rarr; /train endpoint (Smile)</code></td></tr>
# <tr class='even'><td>ML Pipeline</td>         <td><span class='ok'>&#10003; PRESENT</span></td><td class='src'>GradeTrainingController.java:43</td> <td><code class='how'>HashMap encoders &rarr; DataFrame &rarr; fit &rarr; /predict inference</code></td></tr>
#
# <tr><td colspan='4' class='cat' style='background:#b71c1c;'>&#9632;&nbsp; Documentation</td></tr>
# <tr class='hdr'><th>Objective</th><th>Status</th><th>Source</th><th>How</th></tr>
# <tr class='odd'> <td>API Docs (Postman)</td><td><span class='ok'>&#10003; PRESENT</span></td><td class='src'>postman_collection.json</td>          <td><code class='how'>14 folders &bull; 80+ endpoints &bull; {{base_url}} variable</code></td></tr>
# <tr class='even'><td>Blog Portfolio</td>    <td><span class='ok'>&#10003; PRESENT</span></td><td class='src'>nikhil-2026 repo</td>                 <td><code class='how'>FRQ&times;4 &bull; bigO &bull; SRP &bull; calc &bull; year-reflection</code></td></tr>
# <tr class='odd'> <td>Project Impact</td>   <td><span class='ok'>&#10003; PRESENT</span></td><td class='src'>opencodingsociety.com (production)</td><td><code class='how'>Queue &bull; Grade Requests &bull; Capstone &bull; Calendar &bull; WS &bull; Bank &bull; ML &bull; BFS</code></td></tr>
#
# </table></div>
